# %%
import os
import pandas as pd

# %%
# Run once
current_dir = os.getcwd()
par_dir = os.path.dirname(current_dir)
os.chdir(par_dir)

# %%
pwd
# Out:
# 'D:\\Gmail Nuevo\\Estudios\\Cursos\\Springboard\\capstone'

# %%
nyt = pd.read_csv('data/nyt.csv')

# %%
nyt.web_url.loc[19]
# Out:
# 'https://www.nytimes.com/2001/07/29/business/clinton-white-house-export-international-trade-lawyers.html'

# %%
nyt.snippet.loc[19]
# Out:
# 'Clinton White House Export: International Trade Lawyers \xa0As United States trade representative in the Clinton administration, Charlene Barshefsky was at the center of some of the biggest successes — and the one big mess — of recent American econom...'

# %%
nyt.loc[nyt.snippet.str.contains()]
# Out:
#                                                  web_url  \
# 0      https://www.nytimes.com/2001/07/12/business/ad...
# 1      https://www.nytimes.com/2001/07/15/business/a-...
# 2      https://www.nytimes.com/2001/07/16/business/me...
# 3      https://www.nytimes.com/2001/07/17/business/me...
# 4      https://www.nytimes.com/2001/07/17/business/wo...
# 5      https://www.nytimes.com/2001/07/18/business/wo...
# 6      https://www.nytimes.com/2001/07/19/business/wo...
# 7      https://www.nytimes.com/2001/07/19/business/ad...
# 8      https://www.nytimes.com/2001/07/20/business/en...
# 9      https://www.nytimes.com/2001/07/22/business/a-...
# 10     https://www.nytimes.com/2001/07/23/business/me...
# 11     https://www.nytimes.com/2001/07/23/business/gi...
# 12     https://www.nytimes.com/2001/07/24/business/wo...
# 13     https://www.nytimes.com/2001/07/24/business/un...
# 14     https://www.nytimes.com/2001/07/25/business/wo...
# ...

# %%
import os
import pandas as pd

# %%
# Run once
os.chdir('..')
os.chdir('..')
os.chdir('..')

# %%
pwd
# Out:
# 'D:\\coding\\springboard\\capstone\\springboard-capstone-project\\app'

# %%
nyt = pd.read_csv('data/nyt/nyt.csv')
nyt_label = pd.read_csv('data/nyt/nyt_group1_labelled.csv')

# %%
nyt = nyt.merge(nyt_label, how='left', left_on='web_url', right_on='web_url')

# %%
nyt.web_url.loc[19]
# Out:
# 'https://www.nytimes.com/2001/07/29/business/clinton-white-house-export-international-trade-lawyers.html'

# %%
nyt.tail(10)
# Out:
#                                                  web_url  \
# 80195  https://www.nytimes.com/2021/06/30/technology/...
# 80196  https://www.nytimes.com/2021/06/30/business/ta...
# 80197  https://www.nytimes.com/2021/06/30/business/ho...
# 80198  https://www.nytimes.com/2021/06/30/business/de...
# 80199  https://www.nytimes.com/2021/06/30/technology/...
# 80200  https://www.nytimes.com/2021/06/30/business/ga...
# 80201  https://www.nytimes.com/2021/06/30/technology/...
# 80202  https://www.nytimes.com/2021/06/30/technology/...
# 80203  https://www.nytimes.com/2021/06/30/technology/...
# 80204  https://www.nytimes.com/2021/06/30/business/wo...
#
#                        pub_date  \
# 80195  2021-06-30T09:00:20+0000
# 80196  2021-06-30T09:00:32+0000
# 80197  2021-06-30T09:00:32+0000
# 80198  2021-06-30T12:12:02+0000
# 80199  2021-06-30T15:04:08+0000
# 80200  2021-06-30T16:41:38+0000
# 80201  2021-06-30T16:45:16+0000
# 80202  2021-06-30T16:50:19+0000
# 80203  2021-06-30T16:58:39+0000
# ...

# %%
nyt.loc[~nyt.label.isnull()]
# Out:
#                                                  web_url  \
# 20     https://www.nytimes.com/2001/07/29/business/le...
# 52     https://www.nytimes.com/2001/08/16/business/me...
# 92     https://www.nytimes.com/2001/08/31/business/gr...
# 118    https://www.nytimes.com/2001/09/17/business/fe...
# 171    https://www.nytimes.com/2001/10/07/business/ne...
# ...                                                  ...
# 79905  https://www.nytimes.com/2021/05/26/business/am...
# 80049  https://www.nytimes.com/2021/06/12/business/pr...
# 80068  https://www.nytimes.com/2021/06/15/business/ma...
# 80121  https://www.nytimes.com/2021/06/22/business/mo...
# 80166  https://www.nytimes.com/2021/06/28/business/ma...
#
#                        pub_date  \
# 20     2001-07-29T05:00:00+0000
# 52     2001-08-16T05:00:00+0000
# 92     2001-08-31T05:00:00+0000
# 118    2001-09-17T05:00:00+0000
# 171    2001-10-07T05:00:00+0000
# ...                         ...
# 79905  2021-05-26T12:43:41+0000
# ...

# %%
nyt.to_csv('data/nyt/nyt_all_labelled.csv', index=False)
